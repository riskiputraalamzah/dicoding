# %% [markdown]
# # Proyek Klasifikasi Gambar: Animals-10 Dataset
# Di sel Markdown ini, cukup isi data diri Anda:
#
# Nama: Riski Putra Alamzah
#
# Email: riskialamzah1@gmail.com
#
# ID Dicoding: riskiputraalamzah

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
# Install semua library yang dibutuhkan
# !pip install tensorflow
# !pip install datasets
# !pip install tensorflowjs


import requests
from PIL import Image
import io

# --- Import fungsi preprocessing yang benar untuk EfficientNetV2 ---
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input
from tensorflow.keras import regularizers, optimizers, applications

# Import library utama
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import shutil

# Import untuk data loading dan evaluasi
from datasets import load_dataset
from sklearn.metrics import classification_report, confusion_matrix

# Import untuk konversi model
import tensorflowjs as tfjs

# Set random seed untuk hasil yang konsisten
tf.random.set_seed(42)
np.random.seed(42)

print("TensorFlow version:", tf.__version__)
print("Keras version:", keras.__version__)

try:
  tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
  tf.config.experimental_connect_to_cluster(tpu)
  tf.tpu.experimental.initialize_tpu_system(tpu)
  strategy = tf.distribute.TPUStrategy(tpu)
  print('✅ Berhasil terhubung ke TPU!')
  print('Semua perangkat:', tf.config.list_logical_devices('TPU'))
except ValueError:
  print('❌ Gagal terhubung ke TPU. Coba ganti ke GPU atau restart sesi lagi.')

# !nvidia-smi
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<2.1.0,>=1.26.0->tensorflow) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.33.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.13)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.1.5)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.6.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->datasets) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->datasets) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->datasets) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->datasets) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->datasets) (2024.2.0)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 3.1 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: fsspec
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.5.1
#     Uninstalling fsspec-2025.5.1:
#       Successfully uninstalled fsspec-2025.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.8.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# Successfully installed fsspec-2025.3.0
# Collecting tensorflowjs
#   Downloading tensorflowjs-4.22.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: flax>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.10.6)
# Requirement already satisfied: importlib_resources>=5.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (6.5.2)
# Requirement already satisfied: jax>=0.4.13 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.5.2)
# Requirement already satisfied: jaxlib>=0.4.13 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.5.1)
# Requirement already satisfied: tensorflow<3,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (2.18.0)
# Requirement already satisfied: tf-keras>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (2.18.0)
# Requirement already satisfied: tensorflow-decision-forests>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (1.11.0)
# Requirement already satisfied: six<2,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (1.17.0)
# Requirement already satisfied: tensorflow-hub>=0.16.1 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.16.1)
# Collecting packaging~=23.1 (from tensorflowjs)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (1.26.4)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (1.1.1)
# Requirement already satisfied: optax in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.2.5)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.11.16)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.1.74)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (14.0.0)
# Requirement already satisfied: typing_extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (4.14.0)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (6.0.2)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.1.9)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (0.4.1)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (1.15.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (18.1.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (75.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.14.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.37.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.2.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.45.1)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (3.1.1)
# Requirement already satisfied: ydf in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.9.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.16.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2025.6.15)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (2.19.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.1.3)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.11/dist-packages (from optax->flax>=0.7.2->tensorflowjs) (0.1.89)
# Requirement already satisfied: etils[epath,epy] in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.12.2)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.6.0)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (4.12.3)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.20.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2025.2)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex>=0.1.87->optax->flax>=0.7.2->tensorflowjs) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.2->tensorflowjs) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.0.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (2025.3.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.23.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2024.2.0)
# Downloading tensorflowjs-4.22.0-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 2.7 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: packaging, tensorflowjs
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# pandas-gbq 0.29.1 requires google-api-core<3.0.0,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# dataproc-spark-connect 0.7.5 requires google-api-core>=2.19, but you have google-api-core 1.34.1 which is incompatible.
# db-dtypes 1.4.3 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.8.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed packaging-23.2 tensorflowjs-4.22.0
# 2025-09-06 09:42:23.470919: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757151743.862237      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757151743.976309      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# <p style="margin:0px;">🌲 Try <a href="https://ydf.readthedocs.io/en/latest/" target="_blank">YDF</a>, the successor of
#     <a href="https://www.tensorflow.org/decision_forests" target="_blank">TensorFlow
#         Decision Forests</a> using the same algorithms but with more features and faster
#     training!
# </p>
# <div style="display: flex; flex-wrap: wrap; margin:5px;max-width: 880px;">
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             Old code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import tensorflow_decision_forests as tfdf
#
# tf_ds = tfdf.keras.pd_dataframe_to_tf_dataset(ds, label="l")
# model = tfdf.keras.RandomForestModel(label="l")
# model.fit(tf_ds)
# </pre>
#     </div>
#     <div style="width: 5px;"></div>
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             New code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import ydf
#
# model = ydf.RandomForestLearner(label="l").train(ds)
# </pre>
#     </div>
# </div>
# <p style="margin:0px;font-size: 9pt;">(Learn more in the <a
#         href="https://ydf.readthedocs.io/en/latest/tutorial/migrating_to_ydf/" target="_blank">migration
#         guide</a>)</p>
# TensorFlow version: 2.18.0
# Keras version: 3.8.0
# ❌ Gagal terhubung ke TPU. Coba ganti ke GPU atau restart sesi lagi.
# Sat Sep  6 09:42:45 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8             12W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   33C    P8             11W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !rm -rf submission best_model.keras submission.zip transfer_learning_best.keras
# HAPUS CACHE LAMA UNTUK MENGHINDARI KONFLIK
# !rm -rf ./train_cache ./val_cache ./test_cache

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Data Loading
# Di sel ini, kita akan fokus hanya untuk mengunduh dan menyimpan dataset ke direktori lokal.

# %%
# Menggunakan library datasets dari Hugging Face untuk mengunduh
dataset_dir = "./animals10/raw-img"

# Cek apakah dataset sudah ada, jika belum maka unduh dan simpan
if not os.path.exists(dataset_dir) or not os.listdir(dataset_dir):
    print("Dataset tidak ditemukan. Mengunduh dan menyimpan...")
    try:
        # Unduh dataset dari Hugging Face
        dataset = load_dataset("Rapidata/Animals-10", split="train")
        print("Dataset berhasil diunduh!")

        label_to_name = dataset.features['label'].int2str

        # Simpan gambar ke dalam struktur folder per kelas
        os.makedirs(dataset_dir, exist_ok=True)
        for item in dataset:
            class_name = label_to_name(item['label'])
            image = item['image']
            class_dir = os.path.join(dataset_dir, class_name)
            os.makedirs(class_dir, exist_ok=True)

            # Buat nama file unik untuk menghindari tumpang tindih
            filename = f"image_{len(os.listdir(class_dir))}.jpg"
            image_path = os.path.join(class_dir, filename)
            image.save(image_path)

        print("Gambar berhasil disimpan ke direktori lokal.")
    except Exception as e:
        print(f"\nTerjadi error saat mengunduh: {e}")
else:
    print("Dataset sudah ada di direktori lokal. Melewati proses unduh.")

# Analisis singkat jumlah gambar
total_images = sum([len(files) for r, d, files in os.walk(dataset_dir)])
class_names_list = sorted(os.listdir(dataset_dir))
print(f"\nTotal gambar dalam dataset: {total_images}")
print(f"Jumlah kelas: {len(class_names_list)}")
print("Nama kelas:", class_names_list)
# Out:
# Dataset tidak ditemukan. Mengunduh dan menyimpan...
# README.md: 0.00B [00:00, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/319M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/23554 [00:00<?, ? examples/s]
# Dataset berhasil diunduh!
# Gambar berhasil disimpan ke direktori lokal.
#
# Total gambar dalam dataset: 23554
# Jumlah kelas: 10
# Nama kelas: ['Butterfly', 'Cat', 'Chicken', 'Cow', 'Dog', 'Elephant', 'Horse', 'Sheep', 'Spider', 'Squirrel']

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# #### Split Dataset

# %%
# ======================================================================
# BLOK KODE PERSIAPAN DATA BARU (GANTIKAN SEMUA SEL LAMA)
# ======================================================================
import glob
from sklearn.model_selection import train_test_split
import tensorflow as tf

# --- Konfigurasi --
BATCH_SIZE = 32
IMG_SIZE = (150, 150)
SEED = 42
AUTOTUNE = tf.data.AUTOTUNE

# --- 1. Kumpulkan semua path file gambar dan labelnya ---
print("Mengumpulkan path file gambar...")
dataset_dir = "./animals10/raw-img"
image_paths = list(glob.glob(f'{dataset_dir}/*/*.jpg'))
class_names = sorted(os.listdir(dataset_dir))
label_map = {name: i for i, name in enumerate(class_names)}
labels = [label_map[os.path.basename(os.path.dirname(path))] for path in image_paths]
print(f"Ditemukan {len(image_paths)} gambar dalam {len(class_names)} kelas.")

# --- 2. Bagi path file menjadi train (80%) dan sisa (20%) ---
print("Membagi dataset menjadi 80% train, 10% validation, 10% test...")
train_paths, temp_paths, train_labels, temp_labels = train_test_split(
    image_paths, labels, test_size=0.2, random_state=SEED, stratify=labels
)

# --- 3. Bagi sisa (20%) menjadi validation (10%) dan test (10%) ---
val_paths, test_paths, val_labels, test_labels = train_test_split(
    temp_paths, temp_labels, test_size=0.5, random_state=SEED, stratify=temp_labels
)

print(f"Ukuran set training: {len(train_paths)}")
print(f"Ukuran set validasi: {len(val_paths)}")
print(f"Ukuran set testing: {len(test_paths)}")

# --- 4. Buat fungsi untuk memuat dan memproses gambar dari path ---
def process_path(path, label):
    # Baca file
    img = tf.io.read_file(path)
    img = tf.io.decode_jpeg(img, channels=3)
    # Resize
    img = tf.image.resize(img, IMG_SIZE)
    # Ubah label menjadi categorical
    label = tf.one_hot(label, len(class_names))
    return img, label

# --- 5. Buat tf.data.Dataset dari path yang sudah dibagi ---
train_ds = tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
val_ds = tf.data.Dataset.from_tensor_slices((val_paths, val_labels))
test_ds = tf.data.Dataset.from_tensor_slices((test_paths, test_labels))

# --- 6. Terapkan pemrosesan dan optimasi ke setiap dataset ---
print("\nMenerapkan pemrosesan dan optimasi pipeline data...")
# Hapus cache lama untuk memastikan tidak ada konflik
# !rm -rf ./train_cache ./val_cache ./test_cache

# --- Augmentasi Data (dipisahkan agar bisa diterapkan sebelum preprocessing) ---
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
], name='augmentation')

# Pipeline untuk Training Set
train_ds = train_ds.map(process_path, num_parallel_calls=AUTOTUNE)
train_ds = train_ds.cache('./train_cache').shuffle(1000).batch(BATCH_SIZE)
train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=AUTOTUNE)
train_ds = train_ds.map(lambda x, y: (preprocess_input(x), y), num_parallel_calls=AUTOTUNE) # <-- TAMBAHKAN INI
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)


# Pipeline untuk Validation Set
val_ds = val_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.cache('./val_cache').batch(BATCH_SIZE)
val_ds = val_ds.map(lambda x, y: (preprocess_input(x), y), num_parallel_calls=AUTOTUNE) # <-- TAMBAHKAN INI
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# Pipeline untuk Test Set
test_ds = test_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.cache('./test_cache').batch(BATCH_SIZE)
test_ds = test_ds.map(lambda x, y: (preprocess_input(x), y), num_parallel_calls=AUTOTUNE) # <-- TAMBAHKAN INI
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

print("\n✅ Setup dataset dengan preprocessing yang benar telah selesai.")
# Out:
# Mengumpulkan path file gambar...
# Ditemukan 23554 gambar dalam 10 kelas.
# Membagi dataset menjadi 80% train, 10% validation, 10% test...
# Ukuran set training: 18843
# Ukuran set validasi: 2355
# Ukuran set testing: 2356
#
# Menerapkan pemrosesan dan optimasi pipeline data...
# I0000 00:00:1757151815.736599      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1757151815.737386      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# ✅ Setup dataset dengan preprocessing yang benar telah selesai.

# %% [markdown]
# ## Modelling

# %%
# --- 1. Data Augmentation Layer (Didefinisikan terpisah) ---
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
], name='augmentation')

# --- Terapkan augmentasi HANYA pada dataset training ---
# Gunakan .map() untuk menerapkan augmentasi secara efisien di pipeline data
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y),
    num_parallel_calls=tf.data.AUTOTUNE
)
# Pastikan dataset tetap di-prefetch setelahnya untuk menjaga performa
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE)
print("Augmentasi data telah diterapkan pada pipeline data training.")


# --- 2. Fungsi untuk Membuat Model (TANPA augmentasi di dalamnya) ---
def create_transfer_learning_model(input_shape, num_classes):
    base_model = applications.EfficientNetV2B0(
        include_top=False,
        weights='imagenet',
        input_shape=input_shape,
        pooling='avg'
    )
    base_model.trainable = False

    # Model ini sekarang BERSIH dari lapisan augmentasi
    inputs = keras.Input(shape=input_shape)
    # Perhatikan: 'x = data_augmentation(inputs)' DIHAPUS dari sini
    x = base_model(inputs, training=False) # Langsung proses input dengan base_model
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = keras.Model(inputs, outputs)
    return model, base_model

# --- 3. Menyiapkan Strategi dan Membuat Model ---
strategy = tf.distribute.get_strategy()
print(f'Menggunakan strategi: {strategy.__class__.__name__}')

with strategy.scope():
    input_shape = IMG_SIZE + (3,)
    num_classes = len(class_names)
    model, base_model = create_transfer_learning_model(input_shape, num_classes)

    optimizer = optimizers.Adam(learning_rate=1e-3)

    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
model.summary()

# --- 4. Callbacks (Sama seperti sebelumnya) ---
callbacks = [
    keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True, verbose=1),
    keras.callbacks.ModelCheckpoint(filepath='transfer_learning_best.keras', monitor='val_accuracy', save_best_only=True),
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)
]

# --- 5. Training Model (Tahap 1 & 2, sama seperti sebelumnya) ---
if model:
    print("\nMemulai training Tahap 1 (Feature Extraction)...")
    history_extraction = model.fit(
        train_ds, # train_ds sekarang sudah memiliki augmentasi
        epochs=20,
        validation_data=val_ds, # val_ds tidak di-augmentasi
        callbacks=callbacks,
        verbose=1
    )

    print("\nMemulai training Tahap 2 (Fine-Tuning)...")
    base_model.trainable = True

    with strategy.scope():
        model.compile(
            optimizer=optimizers.Adam(learning_rate=1e-5),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )

    history_finetune = model.fit(
        train_ds,
        epochs=20,
        validation_data=val_ds,
        callbacks=callbacks,
        verbose=1
    )
    print("\nTraining selesai!")
# Out:
# Augmentasi data telah diterapkan pada pipeline data training.
# Menggunakan strategi: _DefaultDistributionStrategy
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0_notop.h5
# 24274472/24274472 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetv2-b0 (Functional)  │ (None, 1280)           │     5,919,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        12,810 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,937,242 (22.65 MB)
#  Trainable params: 15,370 (60.04 KB)
#  Non-trainable params: 5,921,872 (22.59 MB)
# Memulai training Tahap 1 (Feature Extraction)...
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1757151839.877043     132 service.cc:148] XLA service 0x7912100137a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1757151839.878757     132 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1757151839.878783     132 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1757151842.405622     132 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   3/589 ━━━━━━━━━━━━━━━━━━━━ 22s 39ms/step - accuracy: 0.1302 - loss: 3.1203
# I0000 00:00:1757151854.156200     132 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 129s 163ms/step - accuracy: 0.6063 - loss: 1.3717 - val_accuracy: 0.9452 - val_loss: 0.1711 - learning_rate: 0.0010
# Epoch 2/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 66s 111ms/step - accuracy: 0.7897 - loss: 0.6951 - val_accuracy: 0.9469 - val_loss: 0.1535 - learning_rate: 0.0010
# Epoch 3/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 65s 109ms/step - accuracy: 0.7967 - loss: 0.6533 - val_accuracy: 0.9541 - val_loss: 0.1514 - learning_rate: 0.0010
# Epoch 4/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 66s 110ms/step - accuracy: 0.8078 - loss: 0.6410 - val_accuracy: 0.9550 - val_loss: 0.1419 - learning_rate: 0.0010
# Epoch 5/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 65s 110ms/step - accuracy: 0.8059 - loss: 0.6219 - val_accuracy: 0.9567 - val_loss: 0.1421 - learning_rate: 0.0010
# Epoch 6/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 65s 109ms/step - accuracy: 0.8085 - loss: 0.6160 - val_accuracy: 0.9529 - val_loss: 0.1504 - learning_rate: 0.0010
# Epoch 7/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8155 - loss: 0.6090
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 65s 109ms/step - accuracy: 0.8155 - loss: 0.6091 - val_accuracy: 0.9524 - val_loss: 0.1503 - learning_rate: 0.0010
# Epoch 8/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 66s 111ms/step - accuracy: 0.8161 - loss: 0.5853 - val_accuracy: 0.9575 - val_loss: 0.1400 - learning_rate: 2.0000e-04
# Epoch 9/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 65s 109ms/step - accuracy: 0.8155 - loss: 0.5747 - val_accuracy: 0.9554 - val_loss: 0.1384 - learning_rate: 2.0000e-04
# Epoch 10/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 65s 109ms/step - accuracy: 0.8225 - loss: 0.5641 - val_accuracy: 0.9605 - val_loss: 0.1343 - learning_rate: 2.0000e-04
# Epoch 11/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 64s 108ms/step - accuracy: 0.8242 - loss: 0.5486 - val_accuracy: 0.9605 - val_loss: 0.1343 - learning_rate: 2.0000e-04
# Epoch 12/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 66s 110ms/step - accuracy: 0.8256 - loss: 0.5429 - val_accuracy: 0.9622 - val_loss: 0.1330 - learning_rate: 2.0000e-04
# Epoch 13/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 64s 108ms/step - accuracy: 0.8241 - loss: 0.5378 - val_accuracy: 0.9597 - val_loss: 0.1340 - learning_rate: 2.0000e-04
# Epoch 14/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 64s 108ms/step - accuracy: 0.8264 - loss: 0.5320 - val_accuracy: 0.9605 - val_loss: 0.1338 - learning_rate: 2.0000e-04
# Epoch 15/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.8312 - loss: 0.5281
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 64s 108ms/step - accuracy: 0.8312 - loss: 0.5281 - val_accuracy: 0.9575 - val_loss: 0.1339 - learning_rate: 2.0000e-04
# Epoch 16/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 65s 108ms/step - accuracy: 0.8326 - loss: 0.5095 - val_accuracy: 0.9588 - val_loss: 0.1330 - learning_rate: 4.0000e-05
# Epoch 17/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 64s 108ms/step - accuracy: 0.8271 - loss: 0.5237 - val_accuracy: 0.9588 - val_loss: 0.1334 - learning_rate: 4.0000e-05
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 12.
#
# Memulai training Tahap 2 (Fine-Tuning)...
# Epoch 1/20
# E0000 00:00:1757153065.851445     130 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1757153065.987434     130 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 588/589 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7094 - loss: 0.8900
# E0000 00:00:1757153163.565827     129 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1757153163.701580     129 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 206s 185ms/step - accuracy: 0.7095 - loss: 0.8897 - val_accuracy: 0.7953 - val_loss: 0.6130 - learning_rate: 1.0000e-05
# Epoch 2/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 68s 114ms/step - accuracy: 0.7775 - loss: 0.6817 - val_accuracy: 0.8297 - val_loss: 0.5160 - learning_rate: 1.0000e-05
# Epoch 3/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 68s 115ms/step - accuracy: 0.8099 - loss: 0.5771 - val_accuracy: 0.8548 - val_loss: 0.4657 - learning_rate: 1.0000e-05
# Epoch 4/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 69s 115ms/step - accuracy: 0.8208 - loss: 0.5495 - val_accuracy: 0.8624 - val_loss: 0.4239 - learning_rate: 1.0000e-05
# Epoch 5/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 68s 114ms/step - accuracy: 0.8391 - loss: 0.5028 - val_accuracy: 0.8879 - val_loss: 0.3671 - learning_rate: 1.0000e-05
# Epoch 6/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 68s 114ms/step - accuracy: 0.8486 - loss: 0.4623 - val_accuracy: 0.8815 - val_loss: 0.3735 - learning_rate: 1.0000e-05
# Epoch 7/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 68s 114ms/step - accuracy: 0.8577 - loss: 0.4227 - val_accuracy: 0.8938 - val_loss: 0.3356 - learning_rate: 1.0000e-05
# Epoch 8/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 68s 115ms/step - accuracy: 0.8714 - loss: 0.4025 - val_accuracy: 0.8917 - val_loss: 0.3280 - learning_rate: 1.0000e-05
# Epoch 9/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 69s 116ms/step - accuracy: 0.8746 - loss: 0.3763 - val_accuracy: 0.9015 - val_loss: 0.3117 - learning_rate: 1.0000e-05
# Epoch 10/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 68s 114ms/step - accuracy: 0.8759 - loss: 0.3647 - val_accuracy: 0.8964 - val_loss: 0.3213 - learning_rate: 1.0000e-05
# Epoch 11/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 68s 114ms/step - accuracy: 0.8851 - loss: 0.3546 - val_accuracy: 0.9036 - val_loss: 0.2989 - learning_rate: 1.0000e-05
# Epoch 12/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 67s 113ms/step - accuracy: 0.8856 - loss: 0.3465 - val_accuracy: 0.9032 - val_loss: 0.3015 - learning_rate: 1.0000e-05
# Epoch 13/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 68s 114ms/step - accuracy: 0.8971 - loss: 0.3144 - val_accuracy: 0.9117 - val_loss: 0.2716 - learning_rate: 1.0000e-05
# Epoch 14/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 68s 114ms/step - accuracy: 0.8972 - loss: 0.3176 - val_accuracy: 0.9032 - val_loss: 0.2954 - learning_rate: 1.0000e-05
# Epoch 15/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 68s 115ms/step - accuracy: 0.8957 - loss: 0.3109 - val_accuracy: 0.9134 - val_loss: 0.2532 - learning_rate: 1.0000e-05
# Epoch 16/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 69s 115ms/step - accuracy: 0.8966 - loss: 0.2997 - val_accuracy: 0.9253 - val_loss: 0.2205 - learning_rate: 1.0000e-05
# Epoch 17/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 68s 114ms/step - accuracy: 0.9090 - loss: 0.2759 - val_accuracy: 0.9168 - val_loss: 0.2416 - learning_rate: 1.0000e-05
# Epoch 18/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 68s 114ms/step - accuracy: 0.9075 - loss: 0.2756 - val_accuracy: 0.9219 - val_loss: 0.2287 - learning_rate: 1.0000e-05
# Epoch 19/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9087 - loss: 0.2772
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 67s 113ms/step - accuracy: 0.9087 - loss: 0.2772 - val_accuracy: 0.9087 - val_loss: 0.2786 - learning_rate: 1.0000e-05
# Epoch 20/20
# 589/589 ━━━━━━━━━━━━━━━━━━━━ 67s 113ms/step - accuracy: 0.9116 - loss: 0.2638 - val_accuracy: 0.9151 - val_loss: 0.2566 - learning_rate: 2.0000e-06
# Restoring model weights from the end of the best epoch: 16.
#
# Training selesai!

# %% [markdown]
# ## Evaluasi dan Visualisasi
# Sel ini akan menampilkan plot akurasi/loss, laporan klasifikasi, dan confusion matrix.

# %%
# Inisialisasi dictionary history gabungan
history_dict = {}

# Gabungkan metrik dari kedua history
for key in history_extraction.history.keys():
    history_dict[key] = history_extraction.history[key] + history_finetune.history[key]

# --- 2. Plot Akurasi dan Loss dari History Gabungan ---
plt.figure(figsize=(15, 5))
# Plot Akurasi
plt.subplot(1, 2, 1)
plt.plot(history_dict['accuracy'], label='Training Accuracy')
plt.plot(history_dict['val_accuracy'], label='Validation Accuracy')
plt.axvline(len(history_extraction.history['accuracy']) - 1, color='r', linestyle='--', label='Akhir Tahap 1') # Penanda
plt.title('Model Accuracy (Gabungan)')
plt.xlabel('Epoch'); plt.ylabel('Accuracy')
plt.legend(); plt.grid(True)
# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history_dict['loss'], label='Training Loss')
plt.plot(history_dict['val_loss'], label='Validation Loss')
plt.axvline(len(history_extraction.history['loss']) - 1, color='r', linestyle='--', label='Akhir Tahap 1') # Penanda
plt.title('Model Loss (Gabungan)')
plt.xlabel('Epoch'); plt.ylabel('Loss')
plt.legend(); plt.grid(True)
plt.show()

# --- 3. Evaluasi pada Test Set ---
# 'EarlyStopping' sudah mengembalikan bobot terbaik secara otomatis
print("\nEvaluasi model pada test set...")
test_loss, test_accuracy = model.evaluate(test_ds, verbose=0)
print(f"Test Accuracy: {test_accuracy*100:.2f}%")

# --- 4. Laporan Klasifikasi dan Confusion Matrix ---
print("\nMembuat laporan klasifikasi dan confusion matrix...")
y_pred_batches = []
y_true_batches = []
for images, labels in test_ds:
    y_pred_batches.append(model.predict(images, verbose=0))
    y_true_batches.append(labels)

y_pred = np.concatenate(y_pred_batches)
y_true = np.concatenate(y_true_batches)

y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_true, axis=1)

print("\nLaporan Klasifikasi:\n", classification_report(y_true_classes, y_pred_classes, target_names=class_names))

plt.figure(figsize=(10, 8))
cm = confusion_matrix(y_true_classes, y_pred_classes)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix'); plt.xlabel('Predicted'); plt.ylabel('True')
plt.show()
# Out:
# Evaluasi model pada test set...
# Test Accuracy: 93.04%
#
# Membuat laporan klasifikasi dan confusion matrix...
#
# Laporan Klasifikasi:
#                precision    recall  f1-score   support
#
#    Butterfly       0.87      0.97      0.91       161
#          Cat       0.92      0.92      0.92       120
#      Chicken       0.94      0.95      0.95       300
#          Cow       0.92      0.85      0.88       180
#          Dog       0.93      0.94      0.94       481
#     Elephant       0.91      0.95      0.93       103
#        Horse       0.95      0.93      0.94       260
#        Sheep       0.87      0.93      0.90       137
#       Spider       0.95      0.94      0.94       434
#     Squirrel       0.98      0.89      0.94       180
#
#     accuracy                           0.93      2356
#    macro avg       0.92      0.93      0.92      2356
# weighted avg       0.93      0.93      0.93      2356

# %% [markdown]
# ## Konversi Model
# Sel terakhir untuk menyimpan model Anda dalam berbagai format yang disyaratkan.

# %%
# Ganti dengan nama file notebook yang Anda unggah
NAMA_FILE_NOTEBOOK = 'notebookb9624d9553.ipynb'
submission_dir = "submission"

# Hapus direktori lama jika ada, lalu buat struktur folder yang baru
if os.path.exists(submission_dir):
    shutil.rmtree(submission_dir)
os.makedirs(os.path.join(submission_dir, "saved_model"), exist_ok=True)
os.makedirs(os.path.join(submission_dir, "tfjs_model"), exist_ok=True)
os.makedirs(os.path.join(submission_dir, "tflite"), exist_ok=True)
print("Direktori submission berhasil dibuat.")

# --- 1. Simpan dalam format SavedModel ---
print("Menyimpan model dalam format SavedModel...")
model.export(os.path.join(submission_dir, "saved_model"))

# --- 2. Simpan dalam format TensorFlow.js ---
print("Menyimpan model dalam format TFJS...")
tfjs.converters.save_keras_model(model, os.path.join(submission_dir, "tfjs_model"))

# --- 3. Simpan dalam format TFLite ---
print("Menyimpan model dalam format TFLite...")
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open(os.path.join(submission_dir, "tflite/model.tflite"), "wb") as f:
    f.write(tflite_model)

# --- 4. Buat file label.txt ---
print("Membuat label.txt...")
with open(os.path.join(submission_dir, "tflite/label.txt"), "w") as f:
    for label in class_names:
        f.write(label + "\n")

# --- 5. Buat file requirements.txt ---
print("Membuat requirements.txt...")
requirements = """
tensorflow
datasets
tensorflowjs
numpy
matplotlib
seaborn
scikit-learn
pillow
"""
with open(os.path.join(submission_dir, "requirements.txt"), "w") as f:
    f.write(requirements.strip())

# --- 6. Buat file README.md ---
print("Membuat README.md...")
readme_content = """
# Proyek Klasifikasi Gambar: Animals-10

Proyek ini dibuat untuk submission kelas "Belajar Pengembangan Machine Learning" di Dicoding.

## Struktur Direktori
submission
├───tfjs_model
| ├───group1-shard1of1.bin
| └───model.json
├───tflite
| ├───model.tflite
| └───label.txt
├───saved_model
| ├───saved_model.pb
| └───variables
├───notebook.ipynb
├───README.md
└───requirements.txt

"""
with open(os.path.join(submission_dir, "README.md"), "w") as f:
    f.write(readme_content.strip())

# --- 7. Salin file notebook ke dalam folder submission ---
print(f"Menyalin notebook {NAMA_FILE_NOTEBOOK}...")
try:
    # Mengganti nama file notebook agar sesuai standar Dicoding
    shutil.copy(NAMA_FILE_NOTEBOOK, os.path.join(submission_dir, "notebook.ipynb"))
except FileNotFoundError:
    print(f"Error: Pastikan nama file notebook Anda adalah '{NAMA_FILE_NOTEBOOK}'")

# --- 8. Buat file zip dari folder submission ---
print("Membuat file submission.zip...")
shutil.make_archive("submission", 'zip', submission_dir)

print("\n✅ SEMUA SELESEI! File 'submission.zip' sudah siap untuk diunduh.")
# Out:
# Direktori submission berhasil dibuat.
# Menyimpan model dalam format SavedModel...
# Saved artifact at 'submission/saved_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name='keras_tensor_279')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   133122377826128: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   133122377825936: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   133122377825552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150056592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150056016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122377825168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122377824400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150058128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150057744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150059088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150058320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150056208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150060048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150059280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150056976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150059664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150061008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150060432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150062544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150063504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150062736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150060240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150064464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150062928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150065232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150063696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150061776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150066768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150066384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150067728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150066960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150064848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150067152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150069072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150070032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150069264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150067920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150070992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150070608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150072144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150071184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150068880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150071760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144125968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144125008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144126160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144125200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144126736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144127888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144128848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144128080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144125584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144128272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144130192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144131152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144130384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144129040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144132112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144131728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144133072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144132304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144130000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144134032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144134224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144132496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144134608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144130576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144135760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144136528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144135376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144135184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144137488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144137104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144138448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144137680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144134416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144139408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144139024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144140368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144139600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144129424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144135952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144137872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144140944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144273616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144272848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144272464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144274960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144273808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144274000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144274192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144276496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144277456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144276688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144275920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144278416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144278032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144279376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144278608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144276304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144280336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144280528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144278800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144280912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144276880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144282064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144282832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144281680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144281488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144276112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144284368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144285328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144284560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144283792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144286288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144285904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144287248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144286480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144284176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144288208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144287440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144288400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144284752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144287824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452704592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452705744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452705168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452704400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452706704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452706320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452707664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452706896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452704208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452708624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452708240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452709584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452708816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452704784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452710544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452710736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452709008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452711120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452707088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452712272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452713040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452711888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452711696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452712464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452714384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452715344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452714576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452713232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452716304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452715920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452717264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452716496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452714192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452718224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452718416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452716688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452718800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452714768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452719952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191183376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452713616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452718608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191182800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191184336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191185296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191184528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191183568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191186256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191185872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191187216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191186448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191184144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191188176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191188368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191186640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191188752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191184720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191189904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191190672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191189520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191189328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191190096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191192016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191192976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191192208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191190864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191193936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191193552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191194896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191194128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191191824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191195856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191196048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191194320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191196432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191192400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191197584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191198544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191197200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191197008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191196240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191789968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191789008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191789776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191788816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191791504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191791120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191792464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191791696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191789200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191793424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191793616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191791888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191794000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191789584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191795152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191795920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191794768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191794576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191796880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191796496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191797840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191797072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191793808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191798800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191798416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191799760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191798992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191790352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191800720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191800912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191799184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191801296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191797264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191802448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191803216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191802064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191801872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191802640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191804560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681657360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191803792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191804368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681657936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681656592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681658896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681658128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681657168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681659856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681660048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681658320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681660432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681656784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681661584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681662352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681661200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681661008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681661776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681663696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681664656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681663888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681662544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681665616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681665232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681666576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681665808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681663504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681667536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681667728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681666000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681668112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681664080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681669264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681670032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681668880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681668688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681669456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681671376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681672528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681671568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681670224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681671760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682246992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682246224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681671184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682247760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682248720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682248912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682247184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682249296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682246416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682250448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682251216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682250064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682249872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682250640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682252560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682253520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682252752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682251408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682254480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682254096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682255440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682254672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682252368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682256400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682256592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682254864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682256976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682252944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682258128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682258896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682257744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682257552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682258320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682260240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682261200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682260432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682259088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682262160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682261776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396558800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682260624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682259472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396559952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396560144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396559568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396560528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396559376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396561680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396562448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396561296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396561104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396561872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396563792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396564752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396563984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396562640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396565712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396565328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396566672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396565904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396563600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396567632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396567824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396566096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396568208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396564176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396569360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396570128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396568976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396568784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396569552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396571472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396572432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396571664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396570320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396573008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396573200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396570704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396573392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396574544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396571856: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Menyimpan model dalam format TFJS...
# failed to lookup keras version from the file,
#     this is likely a weight only file
# Menyimpan model dalam format TFLite...
# Saved artifact at '/tmp/tmpf_py5h6b'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name='keras_tensor_279')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   133122377826128: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   133122377825936: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   133122377825552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150056592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150056016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122377825168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122377824400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150058128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150057744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150059088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150058320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150056208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150060048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150059280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150056976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150059664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150061008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150060432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150062544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150063504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150062736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150060240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150064464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150062928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150065232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150063696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150061776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150066768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150066384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150067728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150066960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150064848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150067152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150069072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150070032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150069264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150067920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150070992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150070608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150072144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150071184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150068880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122150071760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144125968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144125008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144126160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144125200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144126736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144127888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144128848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144128080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144125584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144128272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144130192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144131152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144130384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144129040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144132112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144131728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144133072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144132304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144130000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144134032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144134224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144132496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144134608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144130576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144135760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144136528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144135376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144135184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144137488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144137104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144138448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144137680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144134416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144139408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144139024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144140368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144139600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144129424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144135952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144137872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144140944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144273616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144272848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144272464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144274960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144273808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144274000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144274192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144276496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144277456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144276688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144275920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144278416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144278032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144279376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144278608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144276304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144280336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144280528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144278800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144280912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144276880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144282064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144282832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144281680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144281488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144276112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144284368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144285328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144284560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144283792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144286288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144285904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144287248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144286480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144284176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144288208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144287440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144288400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144284752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133122144287824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452704592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452705744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452705168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452704400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452706704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452706320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452707664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452706896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452704208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452708624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452708240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452709584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452708816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452704784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452710544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452710736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452709008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452711120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452707088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452712272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452713040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452711888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452711696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452712464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452714384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452715344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452714576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452713232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452716304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452715920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452717264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452716496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452714192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452718224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452718416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452716688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452718800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452714768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452719952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191183376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452713616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121452718608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191182800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191184336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191185296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191184528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191183568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191186256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191185872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191187216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191186448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191184144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191188176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191188368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191186640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191188752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191184720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191189904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191190672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191189520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191189328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191190096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191192016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191192976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191192208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191190864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191193936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191193552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191194896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191194128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191191824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191195856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191196048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191194320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191196432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191192400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191197584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191198544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191197200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191197008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191196240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191789968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191789008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191789776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191788816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191791504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191791120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191792464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191791696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191789200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191793424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191793616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191791888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191794000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191789584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191795152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191795920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191794768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191794576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191796880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191796496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191797840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191797072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191793808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191798800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191798416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191799760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191798992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191790352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191800720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191800912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191799184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191801296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191797264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191802448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191803216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191802064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191801872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191802640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191804560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681657360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191803792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133121191804368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681657936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681656592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681658896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681658128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681657168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681659856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681660048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681658320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681660432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681656784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681661584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681662352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681661200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681661008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681661776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681663696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681664656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681663888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681662544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681665616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681665232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681666576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681665808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681663504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681667536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681667728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681666000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681668112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681664080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681669264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681670032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681668880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681668688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681669456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681671376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681672528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681671568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681670224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681671760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682246992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682246224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120681671184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682247760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682248720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682248912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682247184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682249296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682246416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682250448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682251216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682250064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682249872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682250640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682252560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682253520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682252752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682251408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682254480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682254096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682255440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682254672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682252368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682256400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682256592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682254864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682256976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682252944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682258128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682258896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682257744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682257552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682258320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682260240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682261200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682260432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682259088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682262160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682261776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396558800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682260624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120682259472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396559952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396560144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396559568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396560528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396559376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396561680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396562448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396561296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396561104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396561872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396563792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396564752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396563984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396562640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396565712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396565328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396566672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396565904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396563600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396567632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396567824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396566096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396568208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396564176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396569360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396570128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396568976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396568784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396569552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396571472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396572432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396571664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396570320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396573008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396573200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396570704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396573392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396574544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133120396571856: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1757154583.158611      36 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1757154583.158653      36 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1757154583.379004      36 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# Membuat label.txt...
# Membuat requirements.txt...
# Membuat README.md...
# Menyalin notebook notebookb9624d9553.ipynb...
# Error: Pastikan nama file notebook Anda adalah 'notebookb9624d9553.ipynb'
# Membuat file submission.zip...
#
# ✅ SEMUA SELESEI! File 'submission.zip' sudah siap untuk diunduh.

# %% [markdown]
# ## Sel Kode Inferensi

# %%
# --- 1. Load Model Terbaik ---
try:
    saved_model = keras.models.load_model('transfer_learning_best.keras')
    print("Model 'transfer_learning_best.keras' berhasil dimuat.")
except Exception as e:
    print(f"Error saat memuat model: {e}")

# --- 2. Siapkan Gambar Lokal ---
local_image_path = '/kaggle/working/animals10/raw-img/Butterfly/image_1.jpg'
try:
    img = Image.open(local_image_path).convert("RGB")
    print(f"Gambar berhasil dimuat dari: {local_image_path}")
except FileNotFoundError:
    print(f"Error: File tidak ditemukan di {local_image_path}")
    img = None

# --- 3. Preprocessing Gambar ---
if img:
    img_resized = img.resize(IMG_SIZE) # Pastikan IMG_SIZE sudah terdefinisi
    img_array = keras.utils.img_to_array(img_resized)
    img_array = tf.expand_dims(img_array, 0)

    # Preprocessing yang sama dengan saat training
    processed_img_array = preprocess_input(img_array)

    # --- 4. Lakukan Prediksi ---
    predictions = saved_model.predict(processed_img_array)
    
    # --- 5. Tampilkan Hasil ---
    # Tidak perlu softmax lagi karena output model sudah berupa probabilitas
    score = predictions[0]
    predicted_class = class_names[np.argmax(score)] # Pastikan class_names sudah terdefinisi
    confidence = 100 * np.max(score)

    print(f"\nModel memprediksi gambar ini sebagai: {predicted_class}")
    print(f"Dengan tingkat keyakinan: {confidence:.2f}%")

    plt.figure(figsize=(6,6))
    plt.imshow(img)
    plt.title(f"Prediksi: {predicted_class} ({confidence:.2f}%)")
    plt.axis("off")
    plt.show()
# Out:
# Model 'transfer_learning_best.keras' berhasil dimuat.
# Gambar berhasil dimuat dari: /kaggle/working/animals10/raw-img/Butterfly/image_1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
#
# Model memprediksi gambar ini sebagai: Butterfly
# Dengan tingkat keyakinan: 96.26%
